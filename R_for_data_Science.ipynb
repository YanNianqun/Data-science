# %%
library("tidyverse")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.1     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# # Chap 1 : Data Visualization with ggplot2

# %% [markdown]
# ## 1. Asethetic

# %% [markdown]
# ## 2. Farcet

# %%
ggplot(data = mpg) +
geom_point(mapping = aes(x = displ, y = hwy)) +
facet_wrap(~ class, nrow = 2)
# Out:
# plot without title

# %%
ggplot(data = mpg) +
geom_point(mapping = aes(x = displ, y = hwy)) +
facet_grid(drv ~ cyl)
# Out:
# plot without title

# %%
ggplot(data = mpg) +
geom_point(mapping = aes(x = displ, y = hwy)) +
facet_grid( cyl ~ drv)
# Out:
# plot without title

# %%
ggplot(data = mpg) +
geom_point(mapping = aes(x = displ, y = hwy)) +
facet_grid(drv ~ .)
# Out:
# plot without title

# %%
ggplot(data = mpg) +
geom_point(mapping = aes(x = displ, y = hwy)) +
facet_grid(. ~ cyl)
# Out:
# plot without title

# %% [markdown]
# #### (1) What are the advantages to using faceting instead of the color aesthetic? What are the disadvantages? How might the balance change if you had a larger dataset?
# It is easier to look at the individual dataset, but hard to compare with other data.
# Control the factors.
#
# #### (2) Read ?facet_wrap . What does nrow do? What does ncol do? What other options control the layout of the individual panels? Why doesn’t facet_grid() have nrow and ncol variables?
# nrow, ncol: Number of rows and columns. scales.
# facet_grid() forms a matrix of panels defined by row and column faceting variables.
#
# #### (3) When using facet_grid() you should usually put the variable with more unique levels in the columns. Why?
#
# When putting the more levels on the row axis, then the y-axis would shrink so that it is harder to see which actual values are at the points as shown in the plot.
# CHAPTER

# %% [markdown]
# ## 3. Geometric Objects

# %% [markdown]
# A geom is the geometrical object that a plot uses to represent data.
# People often describe plots by the type of geom that the plot uses.

# %%
ggplot(data = mpg) + geom_point(mapping = aes(x = displ, y = hwy))
ggplot(data = mpg)+ geom_smooth(mapping= aes(x= displ,y= hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title

# %%
ggplot(data = mpg) +
geom_smooth(mapping = aes(x = displ, y = hwy, linetype = drv, color = drv))+
geom_point(mapping = aes(x = displ, y = hwy, color = drv))
# Here geom_smooth() separates the cars into three lines based on their drv value
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# Global mapping
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
geom_point() +
geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# Local mapping
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
geom_point(mapping = aes(color = class)) +
geom_smooth(mapping = aes(linetype = drv))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg) +
geom_smooth(mapping = aes(x = displ, y = hwy, group = drv))
# you can set the group aesthetic to a categorical variable to draw multiple objects. 
# ggplot2 will draw a separate object for each unique value of the grouping variable
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg) +
geom_smooth(
mapping = aes(x = displ, y = hwy, color = drv),
#show.legend = FALSE
)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# local override global
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
geom_point(mapping = aes(color = class)) +
geom_smooth(
data = filter(mpg, class == "subcompact"),
se = FALSE
)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
#Exercises
#1. What geom would you use to draw a line chart? A boxplot? A histogram? An area chart?

# line chart two values
ggplot(data=mpg, mapping = aes( x = displ, y= hwy)) + geom_line()
# Out:
# plot without title

# %%
#box plot two values
ggplot(data=mpg, mapping = aes( y = displ, x =class)) + geom_boxplot()
# Out:
# plot without title

# %%
# histgram and bar plot  distrbution of one value
ggplot(data=mpg, mapping = aes(x=displ)) + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(data=mpg, mapping = aes(x=displ)) + geom_bar()
# Out:
# plot without title

# %%
ggplot(
data = mpg,
mapping = aes(x = displ, y = hwy, group = drv)
) +
geom_point() +
geom_smooth(se = FALSE)

ggplot(
data = mpg,
mapping = aes(x = displ, y = hwy, color = drv)
) +
geom_point() +
geom_smooth(se = FALSE)


ggplot(
data = mpg,
mapping = aes(x = displ, y = hwy, color = drv)
) +
geom_point() +
geom_smooth(se = TRUE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title

# %% [markdown]
# #### What does show.legend = FALSE do? What happens if you remove it? Why do you think I used it earlier in the chapter?
# Romove the legend.
#
# #### What does the se argument to geom_smooth() do?
# SE standard error. Turn off the SE display.

# %%
# Will these two graphs look different? Why/why not?
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
geom_point() +
geom_smooth()

ggplot() +
geom_point(
data = mpg,
mapping = aes(x = displ, y = hwy)
) +
geom_smooth(
data = mpg,
mapping = aes(x = displ, y = hwy)
)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title

# %% [markdown]
# #### 6. Re-create the R code necessary to generate the following graphs.

# %%
# why my graph is smaller?
ggplot(data=mpg, mapping = aes(x= displ, y= hwy))+ geom_point()+ geom_smooth(se= FALSE)

ggplot(data=mpg, mapping = aes(x= displ, y= hwy))+ geom_point()+ geom_smooth(aes(group= drv), se= FALSE)

ggplot(data=mpg, mapping = aes(x= displ, y= hwy,color= drv))+ geom_point()+ geom_smooth(se= FALSE)

ggplot(data=mpg, mapping = aes(x= displ, y= hwy))+ geom_point(aes(color= drv))+ geom_smooth(se= FALSE)


ggplot(data=mpg, mapping = aes(x= displ, y= hwy))+ geom_point(aes(color= drv))+ geom_smooth(aes(linetype = drv), se= FALSE)

ggplot(data=mpg, mapping = aes(x= displ, y= hwy))+ geom_point(aes(color= drv))

#mapping is not necessary.
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ## 4. Statistical Transformations
#
# Many graphs, like scatterplots, plot the raw values of your dataset.
# Other graphs, like bar charts, calculate new values to plot:
# • Bar charts, histograms, and frequency polygons bin your data
# and then plot bin counts, the number of points that fall in each
# bin.
# • Smoothers fit a model to your data and then plot predictions
# from the model.
# Boxplots compute a robust summary of the distribution and display a specially formatted box.
#
# The algorithm used to calculate new values for a graph is called a
# stat, short for statistical transformation.

# %%
head(diamonds)

ggplot(data = diamonds)+ geom_bar(mapping= aes(x=cut))
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48
# plot without title

# %%
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48

# %% [markdown]
# ### You can generally use geoms and stats interchangeably.
#
# This works because every geom has a default stat, and every stat has
# a default geom.

# %%
ggplot(data = diamonds) + stat_count(aes(x = cut))
# Out:
# plot without title

# %% [markdown]
# ### When you use stat?
#
# + You might want to override the default stat.

# %%
demo <- tribble(
~a,
~b,
"bar_1", 20,
"bar_2", 30,
"bar_3", 40
)
ggplot(data = demo) +
geom_bar(
mapping = aes(x = a, y = b), stat = "identity"
)
# Out:
# plot without title

# %% [markdown]
# + You might want to override the default mapping from transformed variables to aesthetics. For example, you might want to display a bar chart of proportion, rather than count:

# %%
# you might want to display a bar chart of proportion, rather than count:
ggplot(data = diamonds) +
geom_bar(
mapping = aes(x = cut, y = ..prop.., group = 1)
)
# Out:
# plot without title

# %% [markdown]
# + You might want to draw greater attention to the statistical transformation in your code.

# %%
ggplot(data = diamonds) + # stat_summary() , which summarizes the y values for each unique x value,
stat_summary(
mapping = aes(x = cut, y = depth),
fun.min = min,
fun.max = max,
fun = median #?
)
# Out:
# plot without title

# %% [markdown]
# ### Exercises

# %% [markdown]
# **1. What is the default geom associated with stat_summary() ?
# How could you rewrite the previous plot to use that geom func‐
# tion instead of the stat function?**

# %%
# stat_summary() , which summarizes the y values for each unique x value,
# pointrange and line range(line multi values)
# %>% pip
diamonds %>% group_by(cut) %>% summarize(median_y = median(depth),
                                         min_y = min(depth),
                                         max_y = max(depth)) %>%
  ggplot() +
  geom_pointrange(mapping = aes(x = cut, y = median_y, ymin = min_y, ymax = max_y)) +
  labs(y = 'depth')
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
# plot without title

# %% [markdown]
# **2. What does geom_col() do? How is it different to geom_bar() ?**

# %%
ggplot(data = diamonds, aes(x=cut , y= price)) + geom_col()# use stat_identity # bar use stat_count
# Out:
# plot without title

# %% [markdown]
# 3. What variables does stat_smooth() compute? What parameters control its behavior?
# The method argument defines the smoothing method and the variables to compute. The arguments n, span, fullrange, and level controls its behaviour.

# %% [markdown]
# 4. Most geoms and stats come in pairs that are almost always used in concert.
# Read through the documentation and make a list of all the pairs. What do they have in common?
#
# See this DOC: https://ggplot2.tidyverse.org/reference/

# %% [markdown]
# 5. In our proportion bar chart, we need to set group = 1 . Why? In
# other words what is the problem with these two graphs?

# %% [markdown]
# By default, geom_bar() counts the number of occurances in each level of the variable. However, if we want to display the proportions instead of counts, geom_bar() will treat the groups of the variable separately. Since all diamonds in ‘Fair’ are ‘Fair’, and all diamonds in ‘Ideal’ are ‘Idea’, etc., the proportions will always sum up to 1 for each group by default.

# %%
ggplot(data = diamonds) +
geom_bar(mapping = aes(x = cut, y = ..prop..), groups = 1)
ggplot(data = diamonds) +
geom_bar(
mapping = aes(x = cut, fill = color, y = ..prop.., group = 1)
)
# Out:
# Warning message:
# “Ignoring unknown parameters: groups”
# plot without title
# plot without title

# %% [markdown]
# ## 5. Position Adjustments

# %% [markdown]
# 1. fill

# %%
ggplot(data = diamonds) + geom_bar(mapping = aes(x = cut, color = cut))
ggplot(data = diamonds) + geom_bar(aes(x = cut, fill = cut))
# Out:
# plot without title
# plot without title

# %% [markdown]
# + Note what happens if you map the fill aesthetic to another vari‐
# able, like clarity : the bars are automatically stacked. Each colored
# rectangle represents a combination of cut and clarity

# %%
ggplot(data = diamonds) +
geom_bar(mapping = aes(x = cut, fill = clarity))
# Out:
# plot without title

# %% [markdown]
# 2. position = "identity" will place each object exactly where it
# falls in the context of the graph

# %% [markdown]
# + position = "identity" will place each object exactly where it
# falls in the context of the graph. This is not very useful for bars,
# because it overlaps them. To see that overlapping we either need
# to make the bars slightly transparent by setting alpha to a small
# value, or completely transparent by setting fill = NA :

# %%
ggplot(
data = diamonds,
mapping = aes(x = cut, fill = clarity)
) +
geom_bar(alpha = 1/5, position = "identity")
# Out:
# plot without title

# %%
ggplot(
data = diamonds,
mapping = aes(x = cut, color = clarity)) +

geom_bar(fill = NA, position = "identity")
# Out:
# plot without title

# %% [markdown]
# 3. Stacking

# %%
ggplot(data = diamonds) +
geom_bar(
mapping = aes(x = cut, fill = clarity),
position = "fill"
)
# easy to compare proportion
# Out:
# plot without title

# %% [markdown]
# 4. Dodge overlapping objects side-to-side

# %%
ggplot(data = diamonds) +
geom_bar(
mapping = aes(x = cut, fill = clarity),
position = "dodge"
)
# Out:
# plot without title

# %% [markdown]
# 5. jitter

# %% [markdown]
# sovling overplotting.
#
# + You can avoid this gridding by setting the position adjustment to
# “jitter.” position = "jitter" adds a small amount of random noise
# to each point. This spreads the points out because no two points are
# likely to receive the same amount of random noise:
#
# + Adding randomness seems like a strange way to improve your plot,
# but while it makes your graph less accurate at small scales, it makes
# your graph more revealing at large scales. Because this is such a use‐
# ful operation, ggplot2 comes with a shorthand for geom_point(posi
# tion = "jitter") : geom_jitter() .

# %%
ggplot(data = mpg) +
geom_point(
mapping = aes(x = displ, y = hwy),
position = "jitter"
)
# Out:
# plot without title

# %% [markdown]
# ##  Excercise

# %% [markdown]
# 1. What is the problem with this plot? How could you improve it?

# %%
ggplot(data = mpg, mapping = aes(x = cty, y = hwy)) +
geom_point() # lots of point are overlaped
ggplot(data = mpg, mapping = aes(x = cty, y = hwy)) +
geom_jitter()
# Out:
# plot without title
# plot without title

# %% [markdown]
# 2. What parameters to geom_jitter() control the amount of jit‐
# tering?
# width and hight

# %% [markdown]
# 3. Compare and contrast geom_jitter() with geom_count().
# geom_count shows how many point overlapped.
# geom_jitter add noise to show all points.

# %%
ggplot(mpg, aes(cty, hwy)) +
 geom_point()

ggplot(mpg, aes(cty, hwy)) +
 geom_count()
# Out:
# plot without title
# plot without title

# %% [markdown]
# 4. What’s the default position adjustment for geom_boxplot() ?
# Create a visualization of the mpg dataset that demonstrates it.
#
# Doge2()

# %%
ggplot(mpg, aes(x= cty))+ geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# ## Coordinate Systems

# %% [markdown]
# + coord_flip() switches the x- and y-axes. This is useful (for
# example) if you want horizontal boxplots. It’s also useful for
# long labels—it’s hard to get them to fit without overlapping on
# the x-axis:

# %%
ggplot(data = mpg, mapping = aes(x = class, y = hwy)) +
geom_boxplot()

ggplot(mpg, aes(x=class,y=hwy ))+ geom_boxplot()+ coord_flip()
# Out:
# plot without title
# plot without title

# %% [markdown]
# + coord_quickmap() sets the aspect ratio correctly for maps. This
# is very important if you’re plotting spatial data with ggplot2
# (which unfortunately we don’t have the space to cover in this
# book):

# %%
library("maps")
nz <- map_data("nz")
ggplot(nz, aes(long,lat, group = group ))+ geom_polygon(fill= "blue", color= "black")
# Out:
# plot without title

# %%
ggplot(nz, aes(long, lat, group = group)) +
geom_polygon(fill = "white", color = "black") +
coord_quickmap()
# Out:
# plot without title

# %% [markdown]
# 2. coord_polar() uses polar coordinates. Polar coordinates reveal
# an interesting connection between a bar chart and a Coxcomb
# chart:

# %%
#coxcomb
bar <- ggplot(data = diamonds)+ 
geom_bar(mapping = aes(x = cut, fill = cut), show.legend = FALSE, width = 1)+
theme(aspect.ratio = 1) + labs(x = NULL, y = NULL) 
bar +  coord_flip() + coord_polar()
# Out:
# Coordinate system already present. Adding new coordinate system, which will replace the existing one.
# plot without title

# %%
#coxcomb
bar <- ggplot(data = diamonds)+ 
geom_bar(mapping = aes(x = cut, fill = cut), show.legend = FALSE, width = 1)+
theme(aspect.ratio = 1) + labs(x = NULL, y = NULL) 

bar+ coord_polar()
# Out:
# plot without title

# %% [markdown]
# Exercises

# %% [markdown]
# 1. Turn a stacked bar chart into a pie chart using coord_polar() .

# %%
ggplot(data = diamonds)+ geom_bar(aes(x=cut, color = clarity), alpha= 1/5 ,position = "identity")+ coord_polar()
# Out:
# plot without title

# %% [markdown]
# 2. What does labs() do? Read the documentation.
# Set the labels

# %%
p <- ggplot(mtcars, aes(mpg, wt, colour = cyl)) + geom_point()
p + labs(colour = "Cylinders")
p + labs(x = "New x label")
# Out:
# plot without title
# plot without title

# %% [markdown]
# 3. What’s the difference coord_map() between and coord_quickmap()?
# coord_map(), coord_quickmap() sets the aspect ratio correctly for maps.
# quickmap don't need to input project.

# %% [markdown]
# 4. 1. What does the following plot tell you about the relationship
# between city and highway mpg?
# Positive correlated
#   2. Why is coord_fixed() important?
#  A fixed scale coordinate system forces a specified ratio between the physical representation of data units on the axes.
#  The ratio represents the number of units on the y-axis equivalent to one unit on the x-axis. The default, ratio = 1, ensures that one unit on the x-axis is the same length as one unit on the y-axis
#   3. What does geom_abline() do?
#  Adding reference lines (sometimes called rules) to a plot, either horizontal, vertical, or diagonal (specified by slope and intercept).
#  These are useful for annotating plots.

# %%
ggplot(data = mpg, mapping = aes(x = cty, y = hwy)) +
geom_point() +
geom_abline()+ 
coord_fixed()
# Out:
# plot without title

# %% [markdown]
# ## The Layered Grammar of Graphics

# %%
ggplot(data = diamonds) +  geom_bar(aes(x = cut, fill = cut))
# Out:
# plot without title

# %%
# Out:
# Error in UseMethod("filter_"): no applicable method for 'filter_' applied to an object of class "c('integer', 'numeric')"
# Traceback:
#
# 1. filter(x, rep(1, 3), sides = 1)
# 2. filter.default(x, rep(1, 3), sides = 1)
# 3. filter_(.data, .dots = compat_as_lazy_dots(...))

# %% [markdown]
# # Chapter 2 Workflow: Basics

# %% [markdown]
# 1.
#  You will make lots of assignments and <- is a pain to type. Don’t be
# lazy and use = : it will work, but it will cause confusion later. Instead,
# use RStudio’s keyboard shortcut: Alt-– (the minus sign)

# %% [markdown]
# 2. Use another keyboard shortcut to help you fix
# it. Type “this” then press Cmd/Ctrl-↑. That will list all the com‐
# mands you’ve typed that start with those letters. Use the arrow keys
# to navigate, then press Enter to retype the command.

# %%
ggplot(data = mpg) +
geom_point(mapping = aes(x = displ, y = hwy))
# Out:
# plot without title

# %%
filter(mpg, cyl == 8)
# Out:
#    manufacturer model                  displ year cyl trans      drv cty hwy fl
# 1  audi         a6 quattro             4.2   2008 8   auto(s6)   4   16  23  p
# 2  chevrolet    c1500 suburban 2wd     5.3   2008 8   auto(l4)   r   14  20  r
# 3  chevrolet    c1500 suburban 2wd     5.3   2008 8   auto(l4)   r   11  15  e
# 4  chevrolet    c1500 suburban 2wd     5.3   2008 8   auto(l4)   r   14  20  r
# 5  chevrolet    c1500 suburban 2wd     5.7   1999 8   auto(l4)   r   13  17  r
# 6  chevrolet    c1500 suburban 2wd     6.0   2008 8   auto(l4)   r   12  17  r
# 7  chevrolet    corvette               5.7   1999 8   manual(m6) r   16  26  p
# 8  chevrolet    corvette               5.7   1999 8   auto(l4)   r   15  23  p
# 9  chevrolet    corvette               6.2   2008 8   manual(m6) r   16  26  p
# 10 chevrolet    corvette               6.2   2008 8   auto(s6)   r   15  25  p
# 11 chevrolet    corvette               7.0   2008 8   manual(m6) r   15  24  p
# 12 chevrolet    k1500 tahoe 4wd        5.3   2008 8   auto(l4)   4   14  19  r
# 13 chevrolet    k1500 tahoe 4wd        5.3   2008 8   auto(l4)   4   11  14  e
# 14 chevrolet    k1500 tahoe 4wd        5.7   1999 8   auto(l4)   4   11  15  r
# 15 chevrolet    k1500 tahoe 4wd        6.5   1999 8   auto(l4)   4   14  17  d
# 16 dodge        dakota pickup 4wd      4.7   2008 8   auto(l5)   4   14  19  r
# 17 dodge        dakota pickup 4wd      4.7   2008 8   auto(l5)   4   14  19  r
# 18 dodge        dakota pickup 4wd      4.7   2008 8   auto(l5)   4    9  12  e
# 19 dodge        dakota pickup 4wd      5.2   1999 8   manual(m5) 4   11  17  r
# 20 dodge        dakota pickup 4wd      5.2   1999 8   auto(l4)   4   11  15  r
# 21 dodge        durango 4wd            4.7   2008 8   auto(l5)   4   13  17  r
# 22 dodge        durango 4wd            4.7   2008 8   auto(l5)   4    9  12  e
# 23 dodge        durango 4wd            4.7   2008 8   auto(l5)   4   13  17  r
# 24 dodge        durango 4wd            5.2   1999 8   auto(l4)   4   11  16  r
# 25 dodge        durango 4wd            5.7   2008 8   auto(l5)   4   13  18  r
# 26 dodge        durango 4wd            5.9   1999 8   auto(l4)   4   11  15  r
# 27 dodge        ram 1500 pickup 4wd    4.7   2008 8   manual(m6) 4   12  16  r
# 28 dodge        ram 1500 pickup 4wd    4.7   2008 8   auto(l5)   4    9  12  e
# 29 dodge        ram 1500 pickup 4wd    4.7   2008 8   auto(l5)   4   13  17  r
# 30 dodge        ram 1500 pickup 4wd    4.7   2008 8   auto(l5)   4   13  17  r
# ⋮  ⋮            ⋮                      ⋮     ⋮    ⋮   ⋮          ⋮   ⋮   ⋮   ⋮
# 41 ford         explorer 4wd           5.0   1999 8   auto(l4)   4   13  17  r
# 42 ford         f150 pickup 4wd        4.6   1999 8   manual(m5) 4   13  16  r
# 43 ford         f150 pickup 4wd        4.6   1999 8   auto(l4)   4   13  16  r
# 44 ford         f150 pickup 4wd        4.6   2008 8   auto(l4)   4   13  17  r
# 45 ford         f150 pickup 4wd        5.4   1999 8   auto(l4)   4   11  15  r
# 46 ford         f150 pickup 4wd        5.4   2008 8   auto(l4)   4   13  17  r
# 47 ford         mustang                4.6   1999 8   auto(l4)   r   15  21  r
# 48 ford         mustang                4.6   1999 8   manual(m5) r   15  22  r
# 49 ford         mustang                4.6   2008 8   manual(m5) r   15  23  r
# 50 ford         mustang                4.6   2008 8   auto(l5)   r   15  22  r
# 51 ford         mustang                5.4   2008 8   manual(m6) r   14  20  p
# 52 jeep         grand cherokee 4wd     4.7   1999 8   auto(l4)   4   14  17  r
# 53 jeep         grand cherokee 4wd     4.7   2008 8   auto(l5)   4    9  12  e
# 54 jeep         grand cherokee 4wd     4.7   2008 8   auto(l5)   4   14  19  r
# 55 jeep         grand cherokee 4wd     5.7   2008 8   auto(l5)   4   13  18  r
# 56 jeep         grand cherokee 4wd     6.1   2008 8   auto(l5)   4   11  14  p
# 57 land rover   range rover            4.0   1999 8   auto(l4)   4   11  15  p
# 58 land rover   range rover            4.2   2008 8   auto(s6)   4   12  18  r
# 59 land rover   range rover            4.4   2008 8   auto(s6)   4   12  18  r
# 60 land rover   range rover            4.6   1999 8   auto(l4)   4   11  15  p
# 61 lincoln      navigator 2wd          5.4   1999 8   auto(l4)   r   11  17  r
# 62 lincoln      navigator 2wd          5.4   1999 8   auto(l4)   r   11  16  p
# 63 lincoln      navigator 2wd          5.4   2008 8   auto(l6)   r   12  18  r
# 64 mercury      mountaineer 4wd        4.6   2008 8   auto(l6)   4   13  19  r
# 65 mercury      mountaineer 4wd        5.0   1999 8   auto(l4)   4   13  17  r
# 66 nissan       pathfinder 4wd         5.6   2008 8   auto(s5)   4   12  18  p
# 67 pontiac      grand prix             5.3   2008 8   auto(s4)   f   16  25  p
# 68 toyota       4runner 4wd            4.7   2008 8   auto(l5)   4   14  17  r
# 69 toyota       land cruiser wagon 4wd 4.7   1999 8   auto(l4)   4   11  15  r
# 70 toyota       land cruiser wagon 4wd 5.7   2008 8   auto(s6)   4   13  18  r
#    class
# 1  midsize
# 2  suv
# 3  suv
# 4  suv
# 5  suv
# 6  suv
# 7  2seater
# 8  2seater
# 9  2seater
# 10 2seater
# 11 2seater
# 12 suv
# 13 suv
# 14 suv
# 15 suv
# 16 pickup
# 17 pickup
# 18 pickup
# 19 pickup
# 20 pickup
# 21 suv
# 22 suv
# 23 suv
# 24 suv
# 25 suv
# 26 suv
# 27 pickup
# 28 pickup
# 29 pickup
# 30 pickup
# ⋮  ⋮
# 41 suv
# 42 pickup
# 43 pickup
# 44 pickup
# 45 pickup
# 46 pickup
# 47 subcompact
# 48 subcompact
# 49 subcompact
# 50 subcompact
# 51 subcompact
# 52 suv
# 53 suv
# 54 suv
# 55 suv
# 56 suv
# 57 suv
# 58 suv
# 59 suv
# 60 suv
# 61 suv
# 62 suv
# 63 suv
# 64 suv
# 65 suv
# 66 suv
# 67 midsize
# 68 suv
# 69 suv
# 70 suv

# %%
filter(diamonds, carat > 3)
# Out:
#    carat cut       color clarity depth table price x     y     z
# 1  3.01  Premium   I     I1      62.7  58     8040  9.10  8.97 5.67
# 2  3.11  Fair      J     I1      65.9  57     9823  9.15  9.02 5.98
# 3  3.01  Premium   F     I1      62.2  56     9925  9.24  9.13 5.73
# 4  3.05  Premium   E     I1      60.9  58    10453  9.26  9.25 5.66
# 5  3.02  Fair      I     I1      65.2  56    10577  9.11  9.02 5.91
# 6  3.01  Fair      H     I1      56.1  62    10761  9.54  9.38 5.31
# 7  3.65  Fair      H     I1      67.1  53    11668  9.53  9.48 6.38
# 8  3.24  Premium   H     I1      62.1  58    12300  9.44  9.40 5.85
# 9  3.22  Ideal     I     I1      62.6  55    12545  9.49  9.42 5.92
# 10 3.50  Ideal     H     I1      62.8  57    12587  9.65  9.59 6.03
# 11 3.01  Premium   G     SI2     59.8  58    14220  9.44  9.37 5.62
# 12 4.01  Premium   I     I1      61.0  61    15223 10.14 10.10 6.17
# 13 4.01  Premium   J     I1      62.5  62    15223 10.02  9.94 6.24
# 14 3.04  Very Good I     SI2     63.2  59    15354  9.14  9.07 5.75
# 15 3.40  Fair      D     I1      66.8  52    15964  9.42  9.34 6.27
# 16 4.00  Very Good I     I1      63.3  58    15984 10.01  9.94 6.31
# 17 3.01  Ideal     J     SI2     61.7  58    16037  9.25  9.20 5.69
# 18 3.67  Premium   I     I1      62.4  56    16193  9.86  9.81 6.13
# 19 3.01  Ideal     J     I1      65.4  60    16538  8.99  8.93 5.86
# 20 4.13  Fair      H     I1      64.8  61    17329 10.00  9.85 6.43
# 21 5.01  Fair      J     I1      65.5  59    18018 10.74 10.54 6.98
# 22 3.01  Premium   I     SI2     60.2  59    18242  9.36  9.31 5.62
# 23 3.01  Fair      I     SI2     65.8  56    18242  8.99  8.94 5.90
# 24 3.01  Fair      I     SI2     65.8  56    18242  8.99  8.94 5.90
# 25 3.01  Good      I     SI2     63.9  60    18242  9.06  9.01 5.77
# 26 3.01  Good      I     SI2     63.9  60    18242  9.06  9.01 5.77
# 27 4.50  Fair      J     I1      65.8  58    18531 10.23 10.16 6.72
# 28 3.04  Premium   I     SI2     59.3  60    18559  9.51  9.46 5.62
# 29 3.01  Good      H     SI2     57.6  64    18593  9.44  9.38 5.42
# 30 3.51  Premium   J     VS2     62.5  59    18701  9.66  9.63 6.03
# 31 3.01  Premium   J     SI2     60.7  59    18710  9.35  9.22 5.64
# 32 3.01  Premium   J     SI2     59.7  58    18710  9.41  9.32 5.59

# %% [markdown]
# Alt-Shift-K show all keyboard short cut

# %% [markdown]
# ## CHAPTER 3 Data Transformation with dplyr
